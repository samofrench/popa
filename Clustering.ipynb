# %%
###IMPORTS###

import graphlab as gl
import json, httplib, urllib
gl.product_key.set_product_key('E52C-F8E3-2EC5-D6C4-19A4-DAE1-2367-8E50')
# Out:
# A newer version of GraphLab Create (v1.10.1) is available! Your current version is v1.9.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %%
###GRAB URLs FROM PARSE###
connection = httplib.HTTPSConnection('api.parse.com', 443)
params = urllib.urlencode({"limit":1000})
connection.connect()
connection.request('GET', '/1/classes/Artwork?%s' % params, '', {
       "X-Parse-Application-Id": "CzDFFJj9HWgZpbeH35snFqUxhta3OT7mrvEPcaPe",
       "X-Parse-REST-API-Key": "dD0Kuvi4Tzucit7Q5QDG4ncEsXCV7iJat56vZUw6"
     })
result = json.loads(connection.getresponse().read())
result
# Out:
# {u'results': [{u'ACL': {u'*': {u'read': True},
#     u'GMAAnO5R9U': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': None,
#    u'collection_index': 6,
#    u'createdAt': u'2016-04-15T05:08:45.902Z',
#    u'depth': None,
#    u'description': None,
#    u'height': 38,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1460696923/tracip/art/szhr0yr2wualrm0f2spz.jpg',
#    u'is_framed': False,
#    u'is_primary': True,
#    u'medium': [u'Acrylic', u'Pencil', u'Oil pastel'],
#    u'metadata': {u'bytes': 897767,
#     u'colors': [[u'#9DA29E', 7.7],
#      [u'#93908C', 7.4],
#      [u'#B3AAA6', 6.5],
#      [u'#AE7A84', 5.2],
#      [u'#DC566A', 4.5],
#      [u'#697D82', 4.4],
#      [u'#605852', 4.1],
#      [u'#8B7773', 3.9],
#      [u'#738989', 3.9],
#      [u'#A8932F', 3.8],
#      [u'#A79857', 3.8],
#      [u'#D27686', 3.8],
#      [u'#AB9693', 3.8],
#      [u'#CE8D95', 3.8],
#      [u'#707472', 3.7],
#      [u'#ACA498', 3.5],
#      [u'#AB6468', 2.9],
#      [u'#918975', 2.7],
#      [u'#567374', 2.5],
#      [u'#374845', 2.3],
#      [u'#CAA5A7', 2.2],
#      [u'#DF344C', 2.1],
#      [u'#BA2B36', 1.9],
#      [u'#568A88', 1.9],
#      [u'#A99671', 1.8],
#      [u'#CF6A77', 1.2],
#      [u'#C8C3BB', 1.2],
#      [u'#C69465', 1.1],
#      [u'#6D827C', 0.8],
#      [u'#20827C', 0.6],
#      [u'#268886', 0.5],
#      [u'#237E81', 0.4]],
#     u'created_at': u'2016-04-15T05:08:43Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 2118,
#     u'next_cursor': u'e668d6c8e26975484c933e1d3434ba8b',
#     u'predominant': {u'google': [[u'gray', 33.3],
#       [u'brown', 25.6],
#       [u'teal', 21],
#       [u'red', 8.5],
#       [u'green', 7.7]]},
#     u'public_id': u'tracip/art/szhr0yr2wualrm0f2spz',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 497,
#     u'rate_limit_reset_at': u'2016-04-15T06:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1460696923/tracip/art/szhr0yr2wualrm0f2spz.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1460696923/tracip/art/szhr0yr2wualrm0f2spz.jpg',
#     u'version': 1460696923,
#     u'width': 1768},
#    u'no_of_likes': None,
#    u'objectId': u'02gCljPzRF',
#    u'primary_index': 5,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'QwH2XZa8r7'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-04-15T05:24:14.824Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 800,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'2rt33hCXgs'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'uuhq6lnTYc'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'Canvas'],
#    u'title': u'Untitled',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-04-15T05:25:06.433Z',
#    u'weight': 5,
#    u'width': 32},
#   {u'ACL': {u'*': {u'read': True},
#     u'role:admins': {u'write': True},
#     u'zoL3XlzwgH': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'DsrHPasfG6'},
#    u'collection_index': 2,
#    u'createdAt': u'2016-01-23T03:37:39.490Z',
#    u'depth': 2,
#    u'description': None,
#    u'height': 58,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1453520257/jstorq/art/abzophzscn6biq7fgfcs.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'acrylic'],
#    u'metadata': {u'bytes': 1926366,
#     u'colors': [[u'#D4D0CD', 20.1],
#      [u'#B3B1B3', 12.1],
#      [u'#E5DCD7', 11.7],
#      [u'#E9E2DD', 7.6],
#      [u'#DDE2E0', 7],
#      [u'#BEBEC0', 4.8],
#      [u'#C6C1BE', 4.6],
#      [u'#ECE6E3', 4.6],
#      [u'#C3BFC0', 3.3],
#      [u'#A4715A', 2.7],
#      [u'#A09899', 2.5],
#      [u'#ECC6B3', 1.8],
#      [u'#CB9987', 1.7],
#      [u'#956756', 1.6],
#      [u'#A87969', 1.6],
#      [u'#C5BCB9', 1.6],
#      [u'#B58675', 1.2]],
#     u'created_at': u'2016-01-23T03:37:37Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 2079,
#     u'next_cursor': u'bdfcd7b5c99736d0da6729ddeb65d371',
#     u'predominant': {u'google': [[u'gray', 71.1],
#       [u'purple', 12.1],
#       [u'teal', 7],
#       [u'brown', 5.1]]},
#     u'public_id': u'jstorq/art/abzophzscn6biq7fgfcs',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 497,
#     u'rate_limit_reset_at': u'2016-01-23T04:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1453520257/jstorq/art/abzophzscn6biq7fgfcs.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1453520257/jstorq/art/abzophzscn6biq7fgfcs.jpg',
#     u'version': 1453520257,
#     u'width': 1656},
#    u'no_of_likes': None,
#    u'objectId': u'03FAbzcfOS',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'e6BNUq9NmM'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-01-23T03:43:15.552Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1800,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'tpdliNRyM8'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'canvas'],
#    u'title': u'Kudu',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-02-06T10:49:03.665Z',
#    u'weight': None,
#    u'width': 48},
#   {u'ACL': {u'*': {u'read': True},
#     u'S166Hjc3zs': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'SLbdmblbWu'},
#    u'collection_index': None,
#    u'createdAt': u'2016-04-20T05:03:53.806Z',
#    u'depth': 2,
#    u'description': u'My most recent floral series has been inspired by my move to Seattle and the abundant flowers that burst across the landscape. It is amazing to witness the blooms grow and spread so quickly in this environment, I work to translate that energy into my paintings. Fallen #2 can stand very well on its own however it does have a mate in (Fallen #1) - They make an impressive statement hung together.',
#    u'height': 60,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461128631/gennadraper/art/m7pkhz7t2lnj8aej8xpe.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'acrylic'],
#    u'metadata': {u'bytes': 1418560,
#     u'colors': [[u'#B1B1AC', 10.9],
#      [u'#D3D0CC', 9.5],
#      [u'#9DA3A2', 8.3],
#      [u'#BDC1BA', 6.3],
#      [u'#959690', 6.1],
#      [u'#C3BCB1', 5.7],
#      [u'#ACA895', 4.3],
#      [u'#EAE9E7', 4.1],
#      [u'#6F6D52', 3.6],
#      [u'#A59C8C', 3.5],
#      [u'#E3DFD9', 3.4],
#      [u'#A6956D', 2.8],
#      [u'#73756A', 2.7],
#      [u'#887760', 2.1],
#      [u'#CAB593', 2],
#      [u'#504E33', 1.9],
#      [u'#665B38', 1.9],
#      [u'#CAC5B8', 1.9],
#      [u'#323328', 1.8],
#      [u'#4C3329', 1.6],
#      [u'#615F51', 1.6],
#      [u'#7B8272', 1.6],
#      [u'#8F8A73', 1.6],
#      [u'#DECBA4', 1.6],
#      [u'#282419', 1.5],
#      [u'#39463A', 1.4],
#      [u'#748F8B', 1.4],
#      [u'#9CA19A', 1.4],
#      [u'#535549', 1.2],
#      [u'#C89E5F', 0.8],
#      [u'#996D33', 0.7],
#      [u'#30807F', 0.6]],
#     u'created_at': u'2016-04-20T05:03:51Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 2386,
#     u'next_cursor': u'e6ef85e074b2ba2462d326ee44af55c5',
#     u'predominant': {u'google': [[u'brown', 39],
#       [u'yellow', 37.3],
#       [u'teal', 10.3],
#       [u'green', 9.1]]},
#     u'public_id': u'gennadraper/art/m7pkhz7t2lnj8aej8xpe',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 498,
#     u'rate_limit_reset_at': u'2016-04-20T06:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461128631/gennadraper/art/m7pkhz7t2lnj8aej8xpe.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1461128631/gennadraper/art/m7pkhz7t2lnj8aej8xpe.jpg',
#     u'version': 1461128631,
#     u'width': 1418},
#    u'no_of_likes': None,
#    u'objectId': u'08C8p2j6Mf',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'TIjLcL6M42'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-04-20T05:36:28.303Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1800,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'ztm6Gf0AKI'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'}],
#    u'supplimentaryImages': [u'https://res.cloudinary.com/drizlalpha/image/upload/v1461130055/gennadraper/artwork-supplimentaryimages/ovvkngn29tm2qs5euxp6.jpg'],
#    u'surface': [u'canvas'],
#    u'title': u'Fallen #2',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-04-20T05:36:29.144Z',
#    u'weight': 10,
#    u'width': 36},
#   {u'ACL': {u'*': {u'read': True},
#     u'S166Hjc3zs': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'KmED54lPrO'},
#    u'collection_index': None,
#    u'createdAt': u'2016-04-29T01:46:49.167Z',
#    u'depth': 2,
#    u'description': u'',
#    u'height': 48,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461894406/gennadraper/art/vuc2eqfmadqnxrg2y89r.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'Mixed media', u'Acrylic', u'Textiles', u'resin'],
#    u'metadata': {u'bytes': 1696859,
#     u'colors': [[u'#151112', 8.9],
#      [u'#9AA79F', 5.1],
#      [u'#A0391D', 4.9],
#      [u'#5E2C17', 4.8],
#      [u'#624923', 4.2],
#      [u'#B48D27', 4.1],
#      [u'#2F302F', 3.9],
#      [u'#903515', 3.9],
#      [u'#D3A62F', 3.9],
#      [u'#B6C5B7', 3.8],
#      [u'#D4A933', 3.7],
#      [u'#5D655E', 3.5],
#      [u'#394448', 3.4],
#      [u'#2A1C17', 3.3],
#      [u'#D2E0D5', 3],
#      [u'#EDC23D', 2.9],
#      [u'#778A8B', 2.8],
#      [u'#687B84', 2.7],
#      [u'#9D704F', 2.6],
#      [u'#704D2E', 2.5],
#      [u'#9E5B22', 2.4],
#      [u'#F1C84F', 2.3],
#      [u'#914E2A', 2.2],
#      [u'#C86031', 2.2],
#      [u'#CD7548', 2.1],
#      [u'#DAAC51', 2.1],
#      [u'#758479', 1.9],
#      [u'#A58D68', 1.9],
#      [u'#AD502A', 1.6],
#      [u'#F7D56A', 1.4],
#      [u'#C4BEAF', 1.1],
#      [u'#DCD2AB', 1.1]],
#     u'created_at': u'2016-04-29T01:46:46Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 2299,
#     u'next_cursor': u'213fdd0a6705a3e4f88b90decbb3ff15',
#     u'predominant': {u'google': [[u'brown', 54.6],
#       [u'green', 17.3],
#       [u'teal', 12.8],
#       [u'black', 8.9],
#       [u'orange', 6.6]]},
#     u'public_id': u'gennadraper/art/vuc2eqfmadqnxrg2y89r',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 499,
#     u'rate_limit_reset_at': u'2016-04-29T02:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461894406/gennadraper/art/vuc2eqfmadqnxrg2y89r.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1461894406/gennadraper/art/vuc2eqfmadqnxrg2y89r.jpg',
#     u'version': 1461894406,
#     u'width': 2318},
#    u'no_of_likes': None,
#    u'objectId': u'0BjdCPETft',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'TIjLcL6M42'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-04-29T01:52:24.483Z'},
#    u'recommended_matted_border': 0,
#    u'retail_price': 1800,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'nLP3ccEOt9'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'uuhq6lnTYc'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'L05pDQntRO'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'Canvas'],
#    u'title': u'Beans',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-04-29T01:52:25.324Z',
#    u'weight': 18,
#    u'width': 48},
#   {u'ACL': {u'*': {u'read': True},
#     u'BGRhSLFUU0': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'Yj6sDnyz5f'},
#    u'collection_index': None,
#    u'createdAt': u'2016-04-05T08:45:07.692Z',
#    u'depth': None,
#    u'description': None,
#    u'height': 22,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1459845905/bborcher/art/zwajitnzczk4caoq13aj.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'acrylic'],
#    u'metadata': {u'bytes': 3143719,
#     u'colors': [[u'#3B452D', 5.7],
#      [u'#202026', 5.1],
#      [u'#A6CDE3', 5.1],
#      [u'#2C3030', 4.9],
#      [u'#50374D', 4.4],
#      [u'#9AB5CA', 4.3],
#      [u'#2D354F', 4.1],
#      [u'#79856D', 3.6],
#      [u'#9E748D', 3.6],
#      [u'#CBCDD2', 3.6],
#      [u'#4B4F32', 3.5],
#      [u'#8E9490', 3.5],
#      [u'#67602F', 3.4],
#      [u'#B0AEB2', 3.3],
#      [u'#306795', 3.1],
#      [u'#5A6F8D', 3.1],
#      [u'#4F3133', 3],
#      [u'#A16A66', 3],
#      [u'#7195AE', 2.9],
#      [u'#CEACA9', 2.8],
#      [u'#6690A3', 2.6],
#      [u'#69B8DD', 2.6],
#      [u'#B19854', 2.3],
#      [u'#9B936B', 2.2],
#      [u'#68ACD0', 2.2],
#      [u'#36485D', 2],
#      [u'#D5C3B3', 2],
#      [u'#D8DBE4', 1.9],
#      [u'#655F63', 1.8],
#      [u'#9C9EA5', 1.7],
#      [u'#9A4F39', 1.5],
#      [u'#514C50', 1.2]],
#     u'created_at': u'2016-04-05T08:45:05Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 2903,
#     u'next_cursor': u'609a2936eedaa18985b6c69118dd375c',
#     u'predominant': {u'google': [[u'teal', 29.7],
#       [u'blue', 19.5],
#       [u'gray', 14.2],
#       [u'green', 12.8],
#       [u'brown', 9.2],
#       [u'purple', 8.9],
#       [u'yellow', 5.7]]},
#     u'public_id': u'bborcher/art/zwajitnzczk4caoq13aj',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 498,
#     u'rate_limit_reset_at': u'2016-04-05T09:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1459845905/bborcher/art/zwajitnzczk4caoq13aj.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1459845905/bborcher/art/zwajitnzczk4caoq13aj.jpg',
#     u'version': 1459845905,
#     u'width': 3743},
#    u'no_of_likes': None,
#    u'objectId': u'0IOPeOkrv6',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'LExyQr4WmM'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-04-05T08:50:36.795Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1350,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'canvas'],
#    u'title': u'Anticipating Spring',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-04-05T08:50:36.997Z',
#    u'weight': None,
#    u'width': 28},
#   {u'ACL': {u'*': {u'read': True},
#     u'pxXegfYSOi': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'6UJjrIBCam'},
#    u'collection_index': None,
#    u'createdAt': u'2016-04-04T22:50:39.128Z',
#    u'depth': 2,
#    u'description': None,
#    u'height': 36,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1459810236/painternan/art/de3pmn06vs3joxi4knvk.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'ink'],
#    u'metadata': {u'bytes': 2598497,
#     u'colors': [[u'#D8D0B2', 15.9],
#      [u'#D6D3BE', 13.2],
#      [u'#D9C794', 12.7],
#      [u'#E5D1AA', 7.8],
#      [u'#E5CA93', 7],
#      [u'#D9C576', 4.8],
#      [u'#DCA78E', 3.7],
#      [u'#D6B68B', 3.1],
#      [u'#E6B38B', 3.1],
#      [u'#E6946F', 2.8],
#      [u'#D5B372', 2.7],
#      [u'#ADAC94', 2.7],
#      [u'#E7C676', 2.5],
#      [u'#E6B371', 2.1],
#      [u'#F7E2AD', 2],
#      [u'#D5AC55', 1.4],
#      [u'#E7AE54', 1.4],
#      [u'#D77552', 1.2],
#      [u'#DA9732', 1.2],
#      [u'#E69052', 1.2],
#      [u'#D6946F', 1.2],
#      [u'#B19D61', 1.1],
#      [u'#E0C853', 1.1],
#      [u'#D39250', 0.7],
#      [u'#A88F32', 0.6],
#      [u'#D9662D', 0.5],
#      [u'#DDC837', 0.5],
#      [u'#BF301A', 0.4],
#      [u'#A56E55', 0.4],
#      [u'#7C847B', 0.3],
#      [u'#69513A', 0.2],
#      [u'#A3672C', 0.2]],
#     u'created_at': u'2016-04-04T22:50:36Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 4020,
#     u'next_cursor': u'035f7be215fd211c71c95bd1c259f6b6',
#     u'predominant': {u'google': [[u'brown', 78.1], [u'yellow', 17.5]]},
#     u'public_id': u'painternan/art/de3pmn06vs3joxi4knvk',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 496,
#     u'rate_limit_reset_at': u'2016-04-04T23:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1459810236/painternan/art/de3pmn06vs3joxi4knvk.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1459810236/painternan/art/de3pmn06vs3joxi4knvk.jpg',
#     u'version': 1459810236,
#     u'width': 2651},
#    u'no_of_likes': None,
#    u'objectId': u'0K4YqyhxKM',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'oYYb4n3uWE'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-04-04T23:08:57.496Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1200,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'9d29pkgAwB'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'panel'],
#    u'title': u'Sweet Madness of Pansies',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-04-04T23:08:58.423Z',
#    u'weight': 1.5,
#    u'width': 24},
#   {u'ACL': {u'*': {u'read': True},
#     u'5umBQCYAix': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': False,
#    u'collection': None,
#    u'collection_index': 1,
#    u'createdAt': u'2016-02-10T21:16:03.900Z',
#    u'depth': 1,
#    u'description': None,
#    u'height': 24,
#    u'home_collection': None,
#    u'home_collection_index': 2,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1455138960/karlwkaiser/art/pqjmumsm0w76iffhiqhv.jpg',
#    u'is_extracted': False,
#    u'is_framed': True,
#    u'is_primary': False,
#    u'medium': [u'encaustic'],
#    u'metadata': {u'bytes': 371742,
#     u'colors': [[u'#8D7662', 5.7],
#      [u'#928851', 5.4],
#      [u'#7B8335', 5.3],
#      [u'#A8764B', 4.5],
#      [u'#798562', 4.5],
#      [u'#8F572C', 4.4],
#      [u'#8F764D', 4.4],
#      [u'#8F6F33', 4.3],
#      [u'#ACA371', 4.2],
#      [u'#928733', 3.9],
#      [u'#918D6F', 3.9],
#      [u'#74724E', 3.7],
#      [u'#A68B29', 3.7],
#      [u'#575F4E', 3.5],
#      [u'#A8946F', 3.5],
#      [u'#939589', 3.5],
#      [u'#756C34', 3.2],
#      [u'#AF501C', 2.9],
#      [u'#A88D52', 2.8],
#      [u'#915115', 2.5],
#      [u'#A49F8C', 2.5],
#      [u'#A16217', 2.4],
#      [u'#7A8A86', 2.2],
#      [u'#615927', 2],
#      [u'#A87032', 2],
#      [u'#72572E', 1.9],
#      [u'#ADA78D', 1.8],
#      [u'#74786A', 1.7],
#      [u'#787E81', 1.2]],
#     u'created_at': u'2016-02-10T21:16:00Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 662,
#     u'next_cursor': u'bca643857923649d5bdbb699b81fd573',
#     u'predominant': {u'google': [[u'brown', 55.4], [u'yellow', 37.9]]},
#     u'public_id': u'karlwkaiser/art/pqjmumsm0w76iffhiqhv',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 493,
#     u'rate_limit_reset_at': u'2016-02-10T22:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1455138960/karlwkaiser/art/pqjmumsm0w76iffhiqhv.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1455138960/karlwkaiser/art/pqjmumsm0w76iffhiqhv.jpg',
#     u'version': 1455138960,
#     u'width': 1702},
#    u'no_of_likes': None,
#    u'objectId': u'0NP3JBosS1',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'USNVCnrtwM'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-02-10T21:17:35.888Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 2500,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [],
#    u'supplimentaryImages': [],
#    u'surface': [u'wood panel'],
#    u'title': u'Periphery',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-06-09T00:18:24.555Z',
#    u'weight': None,
#    u'width': 60},
#   {u'ACL': {u'*': {u'read': True},
#     u'jbJgXYhQYq': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': False,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'sK1cWfW13t'},
#    u'collection_index': 2,
#    u'createdAt': u'2016-04-20T17:41:57.260Z',
#    u'depth': 1,
#    u'description': u"Title:  Light Above\n\nI love how the light glowing through the petals of this star lilid softens the color and speckles into a diaphanous haze.  I wish I could capture the strong perfume scent that this flower is known for.\n\nFor the past few years I've been painting flowers up so close that they envelope the viewer in their sensuality and rich color. Enlarged, they become almost abstractions from nature without seeing the outer shape or the environment around them. \n\nIn 2012 I qualified to be a signature member of the Northwest Watercolor Society (NWWS). This is earned by being juried into a select number of local chapter and international watercolor society shows sponsored by NWWS.  The initials now follow my signature on recent watercolor paintings that I call Floralscapes.",
#    u'height': 22,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461174100/sandyhaight/art/jqdshkariuwrtl7urfzh.jpg',
#    u'is_extracted': False,
#    u'is_framed': True,
#    u'is_primary': False,
#    u'medium': [u'watercolor'],
#    u'metadata': {u'bytes': 158227,
#     u'colors': [[u'#526853', 6.7],
#      [u'#A9515A', 6.3],
#      [u'#CC96AA', 5.1],
#      [u'#E5DDE1', 5],
#      [u'#CFCDD0', 4.8],
#      [u'#F1EAEA', 4.7],
#      [u'#B2B2C6', 4.1],
#      [u'#C7778A', 3.9],
#      [u'#37473A', 3.7],
#      [u'#CFB6C8', 3.7],
#      [u'#AF778C', 3.5],
#      [u'#94748C', 3.2],
#      [u'#708969', 3.1],
#      [u'#E3B7C9', 3.1],
#      [u'#51413B', 2.8],
#      [u'#9F5E67', 2.8],
#      [u'#BBC5C7', 2.8],
#      [u'#E9D3D5', 2.7],
#      [u'#3C5663', 2.6],
#      [u'#D49898', 2.6],
#      [u'#9E9671', 2.5],
#      [u'#706E8A', 2.3],
#      [u'#B8C4B7', 2.3],
#      [u'#2E3734', 2.2],
#      [u'#D5C8AF', 2.2],
#      [u'#CD9E77', 2.1],
#      [u'#3A4B47', 2],
#      [u'#AA9AA3', 1.9],
#      [u'#D0ACB5', 1.9],
#      [u'#769090', 1.6],
#      [u'#6A6A63', 1.2],
#      [u'#47554B', 0.7]],
#     u'created_at': u'2016-04-20T17:41:40Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 325,
#     u'next_cursor': u'bcf686d742e87bb421fd2bd8292de285',
#     u'predominant': {u'google': [[u'gray', 36.3],
#       [u'pink', 16.9],
#       [u'green', 16.5],
#       [u'teal', 11.2],
#       [u'blue', 6.4]]},
#     u'public_id': u'sandyhaight/art/jqdshkariuwrtl7urfzh',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 499,
#     u'rate_limit_reset_at': u'2016-04-20T18:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461174100/sandyhaight/art/jqdshkariuwrtl7urfzh.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1461174100/sandyhaight/art/jqdshkariuwrtl7urfzh.jpg',
#     u'version': 1461174100,
#     u'width': 432},
#    u'no_of_likes': None,
#    u'objectId': u'0UWWY8XNbT',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'uLVCC9sjTi'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-04-24T20:41:44.754Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1800,
#    u'sold': False,
#    u'style_other': u'Floral',
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'M3wkoQPHIY'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'9d29pkgAwB'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'L05pDQntRO'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'AYZb39C7l6'}],
#    u'supplimentaryImages': [u'https://res.cloudinary.com/drizlalpha/image/upload/v1461530500/sandyhaight/artwork-supplimentaryimages/lywtls75rsshhg9rkkbz.jpg'],
#    u'surface': [u'arches cold press paper'],
#    u'title': u'Light Above',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-05-27T21:35:33.719Z',
#    u'weight': 9,
#    u'width': 27},
#   {u'ACL': {u'*': {u'read': True},
#     u'role:admins': {u'write': True},
#     u'wAp1QWfh43': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': False,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'kLzyhtYwUV'},
#    u'collection_index': None,
#    u'createdAt': u'2016-04-04T20:05:20.996Z',
#    u'depth': 0,
#    u'description': u'\n*Limited Edition of 3, this is #3. \n\nI am very drawn to the beauty of industrial and useful (infra)structures. I love how old and primal materials like steel and wood and stone weather with the effects of the elements and time. In these pieces I use my photography merged with found and made surface to create a new kind of landscape in which industry and the natural world intersect.',
#    u'height': 18,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1459800317/iskra/art/tjiavzmo0fsrfev8zhax.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'archival pigment print'],
#    u'metadata': {u'bytes': 1705235,
#     u'colors': [[u'#FFFFFF', 12.4],
#      [u'#4F4A4B', 6.1],
#      [u'#E13129', 5.4],
#      [u'#A02D26', 4.9],
#      [u'#353233', 4.4],
#      [u'#8F9BA7', 4.4],
#      [u'#AAB8C9', 4.2],
#      [u'#6C514C', 4.1],
#      [u'#614738', 3.9],
#      [u'#443F44', 3.4],
#      [u'#906956', 3.4],
#      [u'#93A9B3', 3.4],
#      [u'#682B24', 3.2],
#      [u'#8E9191', 3.1],
#      [u'#6F6B67', 2.8],
#      [u'#667789', 2.8],
#      [u'#A8AFB3', 2.7],
#      [u'#94B5C8', 2.6],
#      [u'#F14E34', 2.5],
#      [u'#958A71', 2.5],
#      [u'#A6A594', 2.2],
#      [u'#7D827A', 2.1],
#      [u'#4D3534', 2],
#      [u'#748F9E', 2],
#      [u'#7AAAC7', 2],
#      [u'#281919', 1.7],
#      [u'#BCC2B0', 1.4],
#      [u'#A5C7D7', 1.4],
#      [u'#AF5438', 1.3],
#      [u'#D98C59', 0.7],
#      [u'#8BBCE1', 0.7],
#      [u'#C5D3DE', 0.4]],
#     u'created_at': u'2016-04-04T20:05:17Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 1046,
#     u'next_cursor': u'546543d6bed5719f844749d804ebf1ef',
#     u'predominant': {u'google': [[u'gray', 21.1],
#       [u'teal', 21.1],
#       [u'red', 16],
#       [u'white', 12.4],
#       [u'brown', 11.8],
#       [u'blue', 8.6]]},
#     u'public_id': u'iskra/art/tjiavzmo0fsrfev8zhax',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 499,
#     u'rate_limit_reset_at': u'2016-04-04T21:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1459800317/iskra/art/tjiavzmo0fsrfev8zhax.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1459800317/iskra/art/tjiavzmo0fsrfev8zhax.jpg',
#     u'version': 1459800317,
#     u'width': 1365},
#    u'no_of_likes': None,
#    u'objectId': u'0eF7aJolLV',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'u1rsLFY7M6'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-04-04T20:17:38.712Z'},
#    u'recommended_matted_border': 1,
#    u'retail_price': 1150,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [],
#    u'supplimentaryImages': [],
#    u'surface': [u'paper'],
#    u'title': u'South Holgate Gantry',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-04-04T20:17:39.656Z',
#    u'weight': None,
#    u'width': 24},
#   {u'ACL': {u'*': {u'read': True},
#     u'62C1YkJegS': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'gLFz0yEyLP'},
#    u'collection_index': None,
#    u'createdAt': u'2016-01-26T21:43:25.355Z',
#    u'depth': 1.38,
#    u'description': u'Porcelain Girl captures the intensity and vulnerability of femininity. ',
#    u'height': 20,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1453844602/juliadams/art/chfcjwaginryguhoyxip.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'oil'],
#    u'metadata': {u'bytes': 1383288,
#     u'colors': [[u'#171818', 24.8],
#      [u'#181930', 12.7],
#      [u'#1A1D4C', 12.6],
#      [u'#1D2468', 5.1],
#      [u'#29358C', 5],
#      [u'#232C73', 4.1],
#      [u'#1C1F62', 4],
#      [u'#1D211C', 3.4],
#      [u'#1C2257', 3.4],
#      [u'#2A2F2F', 3],
#      [u'#304496', 2.4],
#      [u'#1D232C', 1.9],
#      [u'#494E52', 1.8],
#      [u'#2D3CA2', 1.8],
#      [u'#29344C', 1.4],
#      [u'#344AA9', 1.4],
#      [u'#CCB3AA', 1.4],
#      [u'#3A444C', 1.1]],
#     u'created_at': u'2016-01-26T21:43:22Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 1200,
#     u'next_cursor': u'49f0f024719672ee41fac00271702efb',
#     u'predominant': {u'google': [[u'blue', 57.6],
#       [u'black', 24.8],
#       [u'teal', 5.9],
#       [u'gray', 5.7]]},
#     u'public_id': u'juliadams/art/chfcjwaginryguhoyxip',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 498,
#     u'rate_limit_reset_at': u'2016-01-26T22:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1453844602/juliadams/art/chfcjwaginryguhoyxip.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1453844602/juliadams/art/chfcjwaginryguhoyxip.jpg',
#     u'version': 1453844602,
#     u'width': 1200},
#    u'no_of_likes': None,
#    u'objectId': u'0kozDK49Jh',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'YIut8qmUou'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-01-29T18:04:17.650Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 2200,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'AYZb39C7l6'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'L05pDQntRO'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'nLP3ccEOt9'}],
#    u'supplimentaryImages': [u'https://res.cloudinary.com/drizlalpha/image/upload/v1454090653/juliadams/artwork-supplimentaryimages/fxraxdkconm4plasrnhf.jpg'],
#    u'surface': [u'wood panel'],
#    u'title': u'Porcelain Girl',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-02-06T10:49:07.152Z',
#    u'weight': None,
#    u'width': 20},
#   {u'ACL': {u'*': {u'read': True},
#     u'ne51D051nN': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': False,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'39kBXYnXuM'},
#    u'collection_index': None,
#    u'createdAt': u'2016-01-28T22:05:11.419Z',
#    u'depth': 1,
#    u'description': u"This body of work spans the early nineties to the present. I'm attracted to these portraits of the American countryside. I find an immense amount of interest in the quality of abandoned vehicles and buildings and their influence on the spaces that they inhabit. They stand as token of both man's influence on the landscape as well as their ultimate impermanence.\n\nThe pieces talk about a feeling of place - a peaceful quiet that occurs in the abandoned and forgotten corners of the landscape.",
#    u'height': 31,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1454018669/justinauld/art/connedmlsz01vbsgx508.jpg',
#    u'is_framed': True,
#    u'is_primary': False,
#    u'medium': [u'oil'],
#    u'metadata': {u'bytes': 324114,
#     u'colors': [[u'#050104', 23.4],
#      [u'#FAF7FA', 12.4],
#      [u'#2B0C14', 5],
#      [u'#33281B', 4],
#      [u'#634934', 3.1],
#      [u'#9FA9D5', 3.1],
#      [u'#A296A4', 2.9],
#      [u'#C6C9E2', 2.9],
#      [u'#17122E', 2.8],
#      [u'#312A2E', 2.8],
#      [u'#D8A7A6', 2.8],
#      [u'#655C64', 2.6],
#      [u'#E1D0E2', 2.5],
#      [u'#7B8279', 2.2],
#      [u'#2A1826', 2.1],
#      [u'#EED6F0', 2.1],
#      [u'#5B291F', 2],
#      [u'#2F344A', 1.9],
#      [u'#473B48', 1.8],
#      [u'#394556', 1.8],
#      [u'#4E4953', 1.7],
#      [u'#8F788D', 1.7],
#      [u'#BA8874', 1.5],
#      [u'#7487A7', 1.5],
#      [u'#B0573E', 1.4],
#      [u'#956B60', 1.4],
#      [u'#6E9ADD', 1.4],
#      [u'#D1B6D1', 1.3],
#      [u'#6D7392', 1.2],
#      [u'#D6798C', 1]],
#     u'created_at': u'2016-01-28T22:04:29Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 750,
#     u'next_cursor': u'94de7f82c1bdeb19af070eca79a7a0ed',
#     u'predominant': {u'google': [[u'black', 23.4],
#       [u'purple', 21.5],
#       [u'blue', 14.6],
#       [u'white', 12.4],
#       [u'brown', 11.4],
#       [u'gray', 8.5],
#       [u'red', 5]]},
#     u'public_id': u'justinauld/art/connedmlsz01vbsgx508',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 491,
#     u'rate_limit_reset_at': u'2016-01-28T23:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1454018669/justinauld/art/connedmlsz01vbsgx508.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1454018669/justinauld/art/connedmlsz01vbsgx508.jpg',
#     u'version': 1454018669,
#     u'width': 565},
#    u'no_of_likes': None,
#    u'objectId': u'0q1MTnvDi9',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'OM98c3UOJx'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-03-01T23:53:35.856Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1500,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [],
#    u'supplimentaryImages': [],
#    u'surface': [u'canvas'],
#    u'title': u'Circuit Breaker',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-03-01T23:53:33.545Z',
#    u'weight': 5,
#    u'width': 23},
#   {u'ACL': {u'*': {u'read': True},
#     u'role:admins': {u'write': True},
#     u'voQfNjYvih': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': False,
#    u'collection': None,
#    u'collection_index': None,
#    u'createdAt': u'2016-04-19T16:23:01.813Z',
#    u'depth': None,
#    u'description': None,
#    u'height': None,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461082979/cprimack/art/m02diew1qul6swc136fw.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [],
#    u'metadata': {u'bytes': 740281,
#     u'colors': [[u'#B9B3B1', 19],
#      [u'#C6B7B1', 17.7],
#      [u'#B0B5C3', 9.4],
#      [u'#B4AA98', 7.3],
#      [u'#CCC5B3', 6.3],
#      [u'#C3BFBF', 6.1],
#      [u'#CDC5C3', 4.9],
#      [u'#CD978B', 3.7],
#      [u'#D2CA8F', 3.4],
#      [u'#0B080A', 2.6],
#      [u'#92938C', 2.5],
#      [u'#CEC679', 1.9],
#      [u'#A39B9B', 1.9],
#      [u'#E9AB9A', 1.9],
#      [u'#B7B26F', 1.7],
#      [u'#C6AD93', 1.7],
#      [u'#272322', 1.4],
#      [u'#CE8876', 1],
#      [u'#7389A5', 0.7],
#      [u'#E7D4A9', 0.7],
#      [u'#4D4833', 0.6],
#      [u'#D0C358', 0.5],
#      [u'#9F6F63', 0.4],
#      [u'#7D8367', 0.4],
#      [u'#63605D', 0.3],
#      [u'#C27658', 0.3],
#      [u'#B6A120', 0.3],
#      [u'#A39A60', 0.3],
#      [u'#C7B972', 0.3],
#      [u'#537299', 0.3],
#      [u'#CCAF57', 0.1],
#      [u'#E8DCD4', 0.1]],
#     u'created_at': u'2016-04-19T16:22:59Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 1827,
#     u'next_cursor': u'c0366051d0051b1c2d99ca245e34b707',
#     u'predominant': {u'google': [[u'gray', 56.1],
#       [u'brown', 19.3],
#       [u'yellow', 11.3],
#       [u'blue', 10.4]]},
#     u'public_id': u'cprimack/art/m02diew1qul6swc136fw',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 498,
#     u'rate_limit_reset_at': u'2016-04-19T17:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1461082979/cprimack/art/m02diew1qul6swc136fw.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1461082979/cprimack/art/m02diew1qul6swc136fw.jpg',
#     u'version': 1461082979,
#     u'width': 1820},
#    u'no_of_likes': None,
#    u'objectId': u'0vi8f5845b',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'KhuxtNUx97'},
#    u'published': False,
#    u'published_at': None,
#    u'recommended_matted_border': None,
#    u'retail_price': None,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [],
#    u'supplimentaryImages': [],
#    u'surface': [],
#    u'title': None,
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-04-19T16:23:01.813Z',
#    u'weight': None,
#    u'width': None},
#   {u'ACL': {u'*': {u'read': True},
#     u'BB0ft0jZbs': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': None,
#    u'collection_index': 4,
#    u'createdAt': u'2016-02-09T20:46:38.669Z',
#    u'depth': 2,
#    u'description': None,
#    u'height': 40,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1455050796/rc-cola/art/b2wqzmwqyt774wwkfkxr.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'encaustic'],
#    u'metadata': {u'bytes': 191129,
#     u'colors': [[u'#382C22', 24.4],
#      [u'#36261A', 14.3],
#      [u'#2B1B11', 11.9],
#      [u'#463325', 8.1],
#      [u'#1F160E', 4.9],
#      [u'#482D1D', 2.5],
#      [u'#8F2F1C', 2.4],
#      [u'#431F14', 2.3],
#      [u'#CA7327', 2.2],
#      [u'#8F4D28', 2.1],
#      [u'#CD872C', 1.9],
#      [u'#B07031', 1.7],
#      [u'#70301D', 1.6],
#      [u'#A25E2A', 1.6],
#      [u'#CA601D', 1.5],
#      [u'#AF311C', 1.4],
#      [u'#8D3823', 1.4],
#      [u'#6F452A', 1.3],
#      [u'#997046', 1.3],
#      [u'#723723', 1.2],
#      [u'#C53920', 1.2],
#      [u'#C78E4A', 1.2],
#      [u'#AD5127', 1],
#      [u'#BC8238', 1],
#      [u'#DC8728', 1],
#      [u'#B8854A', 1]],
#     u'created_at': u'2016-02-09T20:46:36Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 400,
#     u'next_cursor': u'b54e0f0fd8a40a3ef141a43c728e3b1d',
#     u'predominant': {u'google': [[u'brown', 91.6]]},
#     u'public_id': u'rc-cola/art/b2wqzmwqyt774wwkfkxr',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 498,
#     u'rate_limit_reset_at': u'2016-02-09T21:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1455050796/rc-cola/art/b2wqzmwqyt774wwkfkxr.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1455050796/rc-cola/art/b2wqzmwqyt774wwkfkxr.jpg',
#     u'version': 1455050796,
#     u'width': 655},
#    u'no_of_likes': None,
#    u'objectId': u'16lIXqBXEL',
#    u'primary_index': 4,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'r4IR9HnTLh'},
#    u'published': False,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-02-09T20:48:39.651Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 5500,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'tpdliNRyM8'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u't4m2qaf1mT'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'wood panel'],
#    u'title': u'Koi',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-05-08T04:56:55.953Z',
#    u'weight': 20,
#    u'width': 60},
#   {u'ACL': {u'*': {u'read': True},
#     u'Sg6XEs4I6i': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': False,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'iRtFcrbHkG'},
#    u'collection_index': 2,
#    u'createdAt': u'2016-03-15T19:40:31.402Z',
#    u'depth': None,
#    u'description': None,
#    u'height': 36,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1458070828/stehanie/art/eowwiljs1prd4djlaq1d.jpg',
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'mixed media'],
#    u'metadata': {u'bytes': 6083812,
#     u'colors': [[u'#FFFFFF', 17.5],
#      [u'#EFE2CC', 17],
#      [u'#DAD0C3', 13.8],
#      [u'#E8D3BA', 6.9],
#      [u'#E7D9C6', 6.7],
#      [u'#D2C8BC', 5.9],
#      [u'#6E2C2D', 3.1],
#      [u'#9B2934', 2],
#      [u'#A5909A', 1.7],
#      [u'#5A2025', 1.6],
#      [u'#6D5672', 1.6],
#      [u'#756774', 1.5],
#      [u'#C48978', 1.5],
#      [u'#764431', 1.4],
#      [u'#F2C39D', 1.4],
#      [u'#8A4831', 1.3],
#      [u'#C73540', 1.3],
#      [u'#E25E59', 1.3],
#      [u'#4D313E', 1.2],
#      [u'#8B748D', 1.2],
#      [u'#EAD8E6', 1.2],
#      [u'#665159', 1.1],
#      [u'#A5738C', 1.1],
#      [u'#56272B', 1],
#      [u'#DBAB9A', 1],
#      [u'#956566', 0.9],
#      [u'#746C8A', 0.9],
#      [u'#728AB0', 0.8],
#      [u'#7894C1', 0.6],
#      [u'#D2B6C4', 0.5],
#      [u'#D07887', 0.4],
#      [u'#667DC0', 0.3]],
#     u'created_at': u'2016-03-15T19:40:28Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 3079,
#     u'next_cursor': u'a89b27100bb5dc8f2528c7bf595e8aba',
#     u'predominant': {u'google': [[u'brown', 54.4],
#       [u'white', 17.5],
#       [u'gray', 9.9],
#       [u'red', 9.3],
#       [u'purple', 5.2]]},
#     u'public_id': u'stehanie/art/eowwiljs1prd4djlaq1d',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 497,
#     u'rate_limit_reset_at': u'2016-03-15T20:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1458070828/stehanie/art/eowwiljs1prd4djlaq1d.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1458070828/stehanie/art/eowwiljs1prd4djlaq1d.jpg',
#     u'version': 1458070828,
#     u'width': 4468},
#    u'no_of_likes': None,
#    u'objectId': u'1ASCbBCVqN',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'EVXl25EDnN'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-03-15T19:42:22.613Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 3000,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [],
#    u'supplimentaryImages': [],
#    u'surface': [u'paper'],
#    u'title': u'B',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-03-15T19:46:14.608Z',
#    u'weight': None,
#    u'width': 60},
#   {u'ACL': {u'*': {u'read': True},
#     u'6BVKulPzxg': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'r9I4AslsSx'},
#    u'collection_index': 3,
#    u'createdAt': u'2016-02-02T05:37:24.766Z',
#    u'depth': 2,
#    u'description': u'New England seaside village detail.',
#    u'height': 36,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1454391439/ricardoduque11/art/pt6vbk8h7kzifsxyxnqv.jpg',
#    u'is_framed': False,
#    u'is_primary': True,
#    u'medium': [],
#    u'metadata': {u'bytes': 554446,
#     u'colors': [[u'#121414', 16.5],
#      [u'#779DA5', 5.9],
#      [u'#2F322E', 5.6],
#      [u'#588693', 5.2],
#      [u'#D0B89D', 5],
#      [u'#FBE7C9', 4.7],
#      [u'#4F524F', 4.4],
#      [u'#443C37', 3.7],
#      [u'#1E4B29', 3.7],
#      [u'#306985', 3.7],
#      [u'#D4C7B2', 3.4],
#      [u'#656761', 3.2],
#      [u'#2B5B70', 2.8],
#      [u'#0A2D5A', 2.7],
#      [u'#497989', 2.7],
#      [u'#48453B', 2.6],
#      [u'#EED1B3', 2.6],
#      [u'#8C7560', 2.3],
#      [u'#9FABA3', 2.2],
#      [u'#ECDBC3', 2.1],
#      [u'#6A9199', 2],
#      [u'#B2C6BE', 2],
#      [u'#172B26', 1.9],
#      [u'#EFD2A8', 1.7],
#      [u'#16281E', 1.6],
#      [u'#6B9134', 1.3],
#      [u'#A3B04B', 1.3]],
#     u'created_at': u'2016-02-02T05:37:19Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 1851,
#     u'next_cursor': u'5ab086fddcfbc517d5c39ebf42f22d92',
#     u'predominant': {u'google': [[u'teal', 27.8],
#       [u'brown', 23.4],
#       [u'green', 18.5],
#       [u'black', 16.5],
#       [u'yellow', 5]]},
#     u'public_id': u'ricardoduque11/art/pt6vbk8h7kzifsxyxnqv',
#     u'rate_limit_allowed': 500,
#     u'rate_limit_remaining': 498,
#     u'rate_limit_reset_at': u'2016-02-02T06:00:00.000Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1454391439/ricardoduque11/art/pt6vbk8h7kzifsxyxnqv.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1454391439/ricardoduque11/art/pt6vbk8h7kzifsxyxnqv.jpg',
#     u'version': 1454391439,
#     u'width': 1839},
#    u'no_of_likes': None,
#    u'objectId': u'1FuKYmexaD',
#    u'primary_index': 5,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'xeJhxkAgov'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-02-02T06:07:18.395Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1100,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'}],
#    u'supplimentaryImages': [],
#    u'surface': [],
#    u'title': u'Cape Cod',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-02-06T10:49:24.873Z',
#    u'weight': 7,
#    u'width': 36},
#   {u'ACL': {u'*': {u'read': True},
#     u'CwboYmlM4I': {u'write': True},
#     u'role:admins': {u'write': True}},
#    u'can_commission_diff_size': False,
#    u'can_hung_without_frame': False,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
# ...
#    u'height': 24,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466434200/jenileeart/art/qelcs0asxsy9cl3f0s1o.jpg',
#    u'is_extracted': False,
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'acrylic paint', u'acrylic', u'mixed media'],
#    u'metadata': {u'bytes': 168780,
#     u'colors': [[u'#2E292D', 10.7],
#      [u'#726657', 6.1],
#      [u'#928972', 5.2],
#      [u'#94948D', 5],
#      [u'#534539', 4.8],
#      [u'#574F4B', 4.3],
#      [u'#6D2915', 4],
#      [u'#6E332C', 3.6],
#      [u'#161419', 3.4],
#      [u'#55251A', 3.4],
#      [u'#605D61', 3.4],
#      [u'#A3885C', 3.4],
#      [u'#A29E91', 3.4],
#      [u'#72706B', 3.2],
#      [u'#4F332E', 2.8],
#      [u'#231F24', 2.7],
#      [u'#844142', 2.7],
#      [u'#7D8081', 2.7],
#      [u'#704C32', 2.6],
#      [u'#91592F', 2.6],
#      [u'#5C1D14', 2.4],
#      [u'#82382C', 2.3],
#      [u'#2B1A19', 2.2],
#      [u'#8F7352', 2.1],
#      [u'#513B42', 1.9],
#      [u'#784520', 1.7],
#      [u'#C19667', 1.7],
#      [u'#AFA78F', 1.6],
#      [u'#AA9370', 1.5],
#      [u'#8E6E59', 1.1],
#      [u'#69574D', 0.8],
#      [u'#C1B498', 0.7]],
#     u'created_at': u'2016-06-20T14:50:00Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 525,
#     u'next_cursor': u'28d80b759ed2d76e8776cbc95de57dbe',
#     u'predominant': {u'google': [[u'brown', 50.8],
#       [u'gray', 20.3],
#       [u'yellow', 8.4],
#       [u'red', 8.3],
#       [u'purple', 6.1]]},
#     u'public_id': u'jenileeart/art/qelcs0asxsy9cl3f0s1o',
#     u'rate_limit_allowed': 2000,
#     u'rate_limit_remaining': 1994,
#     u'rate_limit_reset_at': u'2016-06-20T15:00:00Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466434200/jenileeart/art/qelcs0asxsy9cl3f0s1o.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1466434200/jenileeart/art/qelcs0asxsy9cl3f0s1o.jpg',
#     u'version': 1466434200,
#     u'width': 800},
#    u'no_of_likes': None,
#    u'objectId': u'OjOp4LKzMV',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'lapQ2ANjVH'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-06-20T14:50:54.585Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 1600,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u't4m2qaf1mT'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'Canvas', u'Panel'],
#    u'title': u'As the West Ends',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-06-20T14:53:31.983Z',
#    u'weight': None,
#    u'width': 36},
#   {u'can_commission_diff_size': False,
#    u'can_hung_without_frame': False,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'1fFClkxZ5k'},
#    u'collection_index': None,
#    u'createdAt': u'2016-06-20T15:06:21.622Z',
#    u'depth': 2.5,
#    u'description': u'This work has sold. Pricing above is for a commissioned similar work. Available on either 1.5" or 2.5" wide gallery wrapped canvas, with painted sides.',
#    u'height': 24,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/mzmcqum08sxluojkpqcz.jpg',
#    u'is_extracted': False,
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'acrylic paint', u'acrylic', u'mixed media'],
#    u'metadata': {u'bytes': 634224,
#     u'colors': [[u'#342B25', 7.5],
#      [u'#8D3A12', 5.6],
#      [u'#CCAD71', 5.4],
#      [u'#512B16', 5],
#      [u'#D6CBB2', 4.8],
#      [u'#906F2E', 4.7],
#      [u'#6E592A', 4.3],
#      [u'#4C3226', 3.9],
#      [u'#D9D3C4', 3.8],
#      [u'#734C17', 3.7],
#      [u'#9F6321', 3.5],
#      [u'#90774A', 3.5],
#      [u'#6C3614', 3.4],
#      [u'#63341F', 3.4],
#      [u'#A99667', 3.4],
#      [u'#DAC69A', 3.2],
#      [u'#C99F54', 3.1],
#      [u'#AD8637', 2.8],
#      [u'#CEB78C', 2.6],
#      [u'#C3791F', 2.4],
#      [u'#B3A98E', 2.4],
#      [u'#715128', 2.3],
#      [u'#8E4E17', 2.3],
#      [u'#B0904F', 2.2],
#      [u'#2D1C14', 2.1],
#      [u'#CCBDA4', 2.1],
#      [u'#34241A', 2],
#      [u'#1C1613', 1.6],
#      [u'#675E4E', 1.1],
#      [u'#C99037', 1.1],
#      [u'#BEBDC1', 0.6],
#      [u'#717F8D', 0.5]],
#     u'created_at': u'2016-06-20T15:06:20Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 1501,
#     u'next_cursor': u'8f152ba7133c2099401b08d732b5ac22',
#     u'predominant': {u'google': [[u'brown', 97.6]]},
#     u'public_id': u'jenileeart/art/mzmcqum08sxluojkpqcz',
#     u'rate_limit_allowed': 2000,
#     u'rate_limit_remaining': 1999,
#     u'rate_limit_reset_at': u'2016-06-20T16:00:00Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/mzmcqum08sxluojkpqcz.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/mzmcqum08sxluojkpqcz.jpg',
#     u'version': 1466435180,
#     u'width': 2278},
#    u'no_of_likes': None,
#    u'objectId': u'fJBAAT5VhM',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'lapQ2ANjVH'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-06-20T15:10:31.450Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 2000,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u't4m2qaf1mT'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'Canvas', u'Panel'],
#    u'title': u'Untitled 3',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-06-20T15:10:24.375Z',
#    u'weight': None,
#    u'width': 36},
#   {u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'1fFClkxZ5k'},
#    u'collection_index': None,
#    u'createdAt': u'2016-06-20T15:06:21.622Z',
#    u'depth': 2.5,
#    u'description': u'This work has sold. Pricing above is for a commissioned similar work. Available on either 1.5" or 2.5" wide gallery wrapped canvas, with painted sides.',
#    u'height': 24,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/pr9p76d6b3l4fbx5hime.jpg',
#    u'is_extracted': False,
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'acrylic paint', u'acrylic', u'mixed media'],
#    u'metadata': {u'bytes': 977037,
#     u'colors': [[u'#D3D3D0', 10.8],
#      [u'#352B28', 9.4],
#      [u'#4D3528', 5.8],
#      [u'#694723', 5.7],
#      [u'#221B17', 4.3],
#      [u'#906833', 3.9],
#      [u'#AA6723', 3.9],
#      [u'#6B3A25', 3.8],
#      [u'#91441C', 3.8],
#      [u'#AD8F62', 3.7],
#      [u'#4F3119', 3.1],
#      [u'#E2D6C8', 3.1],
#      [u'#95754B', 3],
#      [u'#C9B69D', 3],
#      [u'#32241B', 2.9],
#      [u'#D9C9AD', 2.9],
#      [u'#3C3C46', 2.7],
#      [u'#BAC3D3', 2.7],
#      [u'#C1BFC2', 2.5],
#      [u'#D0A75E', 2.3],
#      [u'#C18E38', 2.2],
#      [u'#6F3519', 1.8],
#      [u'#B0B8C7', 1.8],
#      [u'#714C2A', 1.7],
#      [u'#5F5B5C', 1.6],
#      [u'#8C5328', 1.5],
#      [u'#A7A6A7', 1.4],
#      [u'#914D19', 1.2],
#      [u'#9BACC5', 1.2],
#      [u'#6C7387', 0.9],
#      [u'#481D0B', 0.8],
#      [u'#7B8597', 0.6]],
#     u'created_at': u'2016-06-20T15:06:20Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 1795,
#     u'next_cursor': u'dc455390d751482369b01fb8e0785d4c',
#     u'predominant': {u'google': [[u'brown', 64.4],
#       [u'gray', 12.4],
#       [u'yellow', 10.8],
#       [u'blue', 9.9]]},
#     u'public_id': u'jenileeart/art/pr9p76d6b3l4fbx5hime',
#     u'rate_limit_allowed': 2000,
#     u'rate_limit_remaining': 1999,
#     u'rate_limit_reset_at': u'2016-06-20T16:00:00Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/pr9p76d6b3l4fbx5hime.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/pr9p76d6b3l4fbx5hime.jpg',
#     u'version': 1466435180,
#     u'width': 2725},
#    u'no_of_likes': None,
#    u'objectId': u'8Su69UmpPG',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'lapQ2ANjVH'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-06-20T15:09:58.377Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 2000,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u't4m2qaf1mT'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'Canvas', u'Panel'],
#    u'title': u'Untitled 2',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-06-20T15:09:51.295Z',
#    u'weight': None,
#    u'width': 36},
#   {u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': {u'__type': u'Pointer',
#     u'className': u'Collection',
#     u'objectId': u'1fFClkxZ5k'},
#    u'collection_index': None,
#    u'createdAt': u'2016-06-20T15:06:21.627Z',
#    u'depth': 2.5,
#    u'description': u'This work has sold. Pricing above is for a commissioned similar work. Available on either 1.5" or 2.5" wide gallery wrapped canvas, with painted sides.',
#    u'height': 24,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/ylhxj0tv2sc4msksipx6.jpg',
#    u'is_extracted': False,
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'acrylic paint', u'acrylic', u'mixed media'],
#    u'metadata': {u'bytes': 675788,
#     u'colors': [[u'#D0CDC8', 11],
#      [u'#CCC6B6', 8.4],
#      [u'#342A29', 6.6],
#      [u'#654A27', 5.3],
#      [u'#A09060', 5.2],
#      [u'#33241A', 5.1],
#      [u'#4E311A', 4.1],
#      [u'#CCC19E', 3.9],
#      [u'#8D6A36', 3.5],
#      [u'#B8AE8E', 3.1],
#      [u'#BEC0B8', 3.1],
#      [u'#1D1916', 3],
#      [u'#4D3227', 2.7],
#      [u'#6E6552', 2.6],
#      [u'#893824', 2.6],
#      [u'#C0A070', 2.5],
#      [u'#271C17', 2.4],
#      [u'#6F3126', 2.4],
#      [u'#C5BCAB', 2.4],
#      [u'#6F502A', 2.2],
#      [u'#403B44', 2.1],
#      [u'#90754A', 2.1],
#      [u'#C6B492', 1.9],
#      [u'#6A311B', 1.6],
#      [u'#97572C', 1.5],
#      [u'#C2764B', 1.5],
#      [u'#B7B1A4', 1.5],
#      [u'#C39B8A', 1.4],
#      [u'#AF966D', 1.3],
#      [u'#E2DDD6', 1.1],
#      [u'#727B86', 1],
#      [u'#A3774D', 0.9]],
#     u'created_at': u'2016-06-20T15:06:20Z',
#     u'derived': [],
#     u'format': u'jpg',
#     u'height': 1602,
#     u'next_cursor': u'4dbe8a9a6a3e2e1fae41999ed9d93d99',
#     u'predominant': {u'google': [[u'brown', 83.4], [u'gray', 8]]},
#     u'public_id': u'jenileeart/art/ylhxj0tv2sc4msksipx6',
#     u'rate_limit_allowed': 2000,
#     u'rate_limit_remaining': 1999,
#     u'rate_limit_reset_at': u'2016-06-20T16:00:00Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/ylhxj0tv2sc4msksipx6.jpg',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1466435180/jenileeart/art/ylhxj0tv2sc4msksipx6.jpg',
#     u'version': 1466435180,
#     u'width': 2387},
#    u'no_of_likes': None,
#    u'objectId': u'c2VhADZ8Ia',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'lapQ2ANjVH'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-06-20T15:08:54.469Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 2000,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [{u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u'mPZO9SptEp'},
#     {u'__type': u'Pointer',
#      u'className': u'RoomStyle',
#      u'objectId': u't4m2qaf1mT'}],
#    u'supplimentaryImages': [],
#    u'surface': [u'Canvas', u'Panel'],
#    u'title': u'Untitled 1',
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-06-20T15:09:21.756Z',
#    u'weight': None,
#    u'width': 36},
#   {u'can_commission_diff_size': True,
#    u'can_hung_without_frame': True,
#    u'collection': None,
#    u'collection_index': None,
#    u'createdAt': u'2016-06-20T21:30:01.646Z',
#    u'depth': 2,
#    u'description': u'This artwork is sold.  Please email us for similar works.',
#    u'height': 32,
#    u'home_collection': None,
#    u'home_collection_index': None,
#    u'image': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466458200/clientart/art/qmlflvdmtdbepe6p5h4v.png',
#    u'is_extracted': False,
#    u'is_framed': False,
#    u'is_primary': False,
#    u'medium': [u'oil'],
#    u'metadata': {u'bytes': 1178175,
#     u'colors': [[u'#2A2F2F', 5.7],
#      [u'#CBD5D2', 5.4],
#      [u'#91A993', 5.3],
#      [u'#576654', 5.2],
#      [u'#4B4F3A', 4.8],
#      [u'#77A19D', 4.4],
#      [u'#B4CECD', 4.1],
#      [u'#313748', 4],
#      [u'#D6E8EB', 3.7],
#      [u'#EBF4F7', 3.7],
#      [u'#D0DDE0', 3.6],
#      [u'#76855A', 3.4],
#      [u'#9EC4AE', 3.4],
#      [u'#92B1AC', 3.2],
#      [u'#758A72', 3.1],
#      [u'#C0C2B3', 3.1],
#      [u'#1F2123', 2.8],
#      [u'#4C564B', 2.8],
#      [u'#6A7789', 2.7],
#      [u'#8E9471', 2.5],
#      [u'#B0C8B4', 2.5],
#      [u'#636E69', 2.4],
#      [u'#917C8D', 2.4],
#      [u'#6A7155', 2.1],
#      [u'#ACD4D8', 1.9],
#      [u'#3C4442', 1.8],
#      [u'#CAA272', 1.8],
#      [u'#A6B2A3', 1.8],
#      [u'#956D58', 1.7],
#      [u'#7CB6C0', 1.7],
#      [u'#89978C', 1.7],
#      [u'#75928D', 1.4]],
#     u'created_at': u'2016-06-20T21:30:00Z',
#     u'derived': [],
#     u'format': u'png',
#     u'height': 686,
#     u'next_cursor': u'9dd00207f663f8d3aa7fcb8315cbf3f8',
#     u'predominant': {u'google': [[u'teal', 45.8],
#       [u'green', 25.8],
#       [u'yellow', 15.9],
#       [u'blue', 6.7]]},
#     u'public_id': u'clientart/art/qmlflvdmtdbepe6p5h4v',
#     u'rate_limit_allowed': 2000,
#     u'rate_limit_remaining': 1999,
#     u'rate_limit_reset_at': u'2016-06-20T22:00:00Z',
#     u'resource_type': u'image',
#     u'secure_url': u'https://res.cloudinary.com/drizlalpha/image/upload/v1466458200/clientart/art/qmlflvdmtdbepe6p5h4v.png',
#     u'type': u'upload',
#     u'url': u'http://res.cloudinary.com/drizlalpha/image/upload/v1466458200/clientart/art/qmlflvdmtdbepe6p5h4v.png',
#     u'version': 1466458200,
#     u'width': 1076},
#    u'no_of_likes': None,
#    u'objectId': u'E8hmqNAn96',
#    u'primary_index': None,
#    u'profile': {u'__type': u'Pointer',
#     u'className': u'Profile',
#     u'objectId': u'RStAb7J5sR'},
#    u'published': True,
#    u'published_at': {u'__type': u'Date', u'iso': u'2016-06-20T21:31:19.714Z'},
#    u'recommended_matted_border': None,
#    u'retail_price': 9200,
#    u'sold': False,
#    u'style_other': None,
#    u'styles': [],
#    u'supplimentaryImages': [],
#    u'surface': [u'canvas'],
#    u'title': u"Jan's Lightness",
#    u'tryout_collection': None,
#    u'tryout_collection_index': None,
#    u'updatedAt': u'2016-06-20T21:31:19.905Z',
#    u'weight': None,
#    u'width': 50}]}

# %%
###TRANSFORM URLs FOR CLOUDINARY###
url_list = []
ourResult = result['results']
for i in ourResult:
    j = i['image']
    if ("png" in j) or ("jpg" in j):
        if not ("pardue" in j):
            j = j.replace("png", "jpg")
            url_list.append(j.replace("upload/", "upload/c_fill,g_center,h_256,w_256/"))

# %%
###USING GRAPHLAB CLASSES###
#Should take a few minutes - grabbing all images. Future iteration will save image number %APPDATA% to just grab deltas
url_sarray = gl.SArray(url_list)
image_sarray = url_sarray.apply(lambda x: gl.Image(x))
#images = gl.SFrame({'image':image_sarray})
# Out:
# 2016-06-22 01:31:55,667 [INFO] graphlab.cython.cy_server, 176: GraphLab Create v1.9 started. Logging: C:\Users\drizl\AppData\Local\Temp\2\graphlab_server_1466559114.log.0
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1460696923/tracip/art/szhr0yr2wualrm0f2spz.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/449c7ccd-816a-4e8e-8de0-1b534ca39696.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453520257/jstorq/art/abzophzscn6biq7fgfcs.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/cbd32517-6ac4-4be3-9be1-f523d652157a.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461128631/gennadraper/art/m7pkhz7t2lnj8aej8xpe.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/8f1b8e32-1aae-4715-91a3-5d19b03c63d1.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461894406/gennadraper/art/vuc2eqfmadqnxrg2y89r.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/05a4efad-4cfe-4502-a4ce-07c4732de5b5.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1459845905/bborcher/art/zwajitnzczk4caoq13aj.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/1e59f4fa-36c0-4641-9118-9caf555d84b6.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1459810236/painternan/art/de3pmn06vs3joxi4knvk.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/254e4a6e-3271-4fc2-98bd-aff499fa6a90.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1455138960/karlwkaiser/art/pqjmumsm0w76iffhiqhv.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/1fae2a27-42d5-4754-82a3-fb91651c0091.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461174100/sandyhaight/art/jqdshkariuwrtl7urfzh.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/033f049e-7c9c-4242-961e-b5bc3ea974a0.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1459800317/iskra/art/tjiavzmo0fsrfev8zhax.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/26f9d4e4-371e-4e9c-aede-7bd4f150e652.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453844602/juliadams/art/chfcjwaginryguhoyxip.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/eaafb441-727c-4cf2-9eeb-4c8ae9518a51.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018669/justinauld/art/connedmlsz01vbsgx508.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/91ddecbc-70e8-4855-b86a-685bd7136a70.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461082979/cprimack/art/m02diew1qul6swc136fw.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/d0579534-b1d8-41ea-a0ce-dafbbe5e9c9b.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1455050796/rc-cola/art/b2wqzmwqyt774wwkfkxr.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/5149fe48-2063-45c6-a6c3-bd395c9d316b.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1458070828/stehanie/art/eowwiljs1prd4djlaq1d.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/f8f7bf24-b6b2-44c3-aa85-1d790e71f85f.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454391439/ricardoduque11/art/pt6vbk8h7kzifsxyxnqv.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/42864569-d93f-400b-bd83-ba8b0234349c.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1456155735/sdemarest/art/lxhewqkmmrpza13rfezl.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/5574c4cb-a890-495b-9d27-72482bddcf7c.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453859653/bborcher/art/nudgvvu13az5i1cvzoyl.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/970ff61e-8f07-423b-acda-3ca16165b9af.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461274411/penelope35/art/wbjmymbdkuu10mtbracf.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/6d774d87-856b-42a5-9ed1-f993741f249d.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454041819/serene/art/vym0e1c0rkgms0aq2nnk.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/6b263ed9-2d07-4ea9-9c91-4c5db0ee71b8.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453568454/johnosgood/art/exxpvzkarltazk2feyfz.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/3832caa2-e851-40c9-88fd-dd3fc12a9f39.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453516796/jstorq/art/lgszazwfahozlcgjh45o.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/3ddf5343-9d02-4efa-a312-8a0c1bfd84c2.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453516779/jstorq/art/lsnwh4f2jkd6stol87mo.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/1a0db079-ff8a-4886-ace9-b102d7f7bc00.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018699/justinauld/art/ok04xcxihj3u9germ1gb.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/534ee860-18a4-4d7b-b123-80f6dc9f917c.jpg
# Downloading https://res.cloudinary.com/artstudiospace/image/upload/c_fill,g_center,h_256,w_256/v1453202561/admin/art/beadquoyvpvruny3f0cp.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/3468a957-561e-40fa-8a0e-d8e668065965.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1455507137/jstorq/art/ehymge67rxkhs0rnx0od.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/b99f727d-fffe-4a4a-a59b-de9b44c88133.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018705/justinauld/art/mieqkep1cscrpsmtqsyr.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/cbc34b7c-6d22-4d60-b607-ff2a098ceed2.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1460580055/jackieavery/art/ip22blfvjgqfzmmtyrwy.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/7f6b7a68-d2ad-4dc5-a29d-d210010ce54c.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454391440/ricardoduque11/art/uor9so9xghylscnrc04j.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/1b476596-4079-4986-9761-6d5e715e7bd3.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454719334/penelope35/art/g5ujumiighiom4u6zfxe.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/6918d510-d8fd-4cd3-aa4c-33daabf244a9.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453516786/jstorq/art/f36ihdosbyhinl03wkem.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/435d32b4-9fbb-4417-b6aa-88169aa0a316.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1457215539/shyamahelin/art/va5er19iinpalcpzlj14.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/79d37a92-958c-4d94-9bb9-608f8db6c4e4.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461193389/simonafoggitt/art/p3kamnopflzvcpwg1fpo.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/3e97a3cb-d642-4739-8b0d-dd1bf0943ca5.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454985405/williampark/art/uobz6fnqpalzatpz8vlx.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/6daa3cbf-fedf-4f81-bc86-a1fa40d8df72.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1455758813/painternan/art/k2zlr1mbpg7tpyue36vn.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/17de117b-4d75-4fe5-98d5-2b92aba0548d.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018672/justinauld/art/cpebcid0l16lubwponia.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/9b0ea124-c0b0-4f80-9d2b-f9af10bac06c.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1462595244/ireneyesley/art/wf5hnatrq6v0hzuim0zg.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/d40d85cd-756c-4e89-b1b4-9a281ed04f5f.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461084640/cprimack/art/qogwanu8w8p9ht6wjetv.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/85930c64-5b7c-4368-9fb5-3db9b42e93bb.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1456446271/kellywilliamsart/art/obzpenl7xueruszrkbmq.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/687f5204-c65d-4fcb-b3d4-6af3fd60efb6.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018705/justinauld/art/yjyawlzg3ycpsggjkfay.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/d1020c4b-e135-4f21-91c1-bfbde6076497.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018680/justinauld/art/rb7nn2cqlzs82ekv9msh.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/d9a91b0e-78b6-481a-9532-c80925ad1ddd.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1455134179/sdemarest/art/xrzarjvw0p7qqpdkhla7.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/9c86793a-a930-458c-9673-51c9dcd40b80.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454169968/petusy%40comcast.net/art/bdbu3jisuw4rzohgjcvv.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/85e63cf7-04bd-44f8-bd8d-02f42cab0d55.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018688/justinauld/art/moitgkoxxbiucu3vvhqb.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/72210bec-9c04-4993-a338-5bd7fa50e91b.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1458012203/anniemeyer/art/fuvbfkou6myvvtb1tarn.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/c09fe447-771b-4ddc-a933-7f8a857cf099.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1455134049/sdemarest/art/ofwvo7z0sruqlboabaus.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/6e557c03-ec07-45cc-87d5-1ae081aa1bc5.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454089373/petusy%40comcast.net/art/ukaba1ps8mvvg2xqn1kp.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/633ccffa-71e2-4d47-a000-43e12ca84ba4.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1455413994/karlwkaiser/art/vqikkaapkw8vkmpllqed.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/6e2f0c45-d5d6-4c6e-9db0-4f1925736921.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453859652/bborcher/art/lvzupmqp1qbwbgkr6kgs.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/cbd91995-f3a2-4b29-84a5-0404c78d4829.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018707/justinauld/art/fbzvqzm9kvo9nhhxtjbp.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/492a4a42-88b6-4af6-a918-131db8343fbb.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453500993/bettyjo/art/aetgvbu4kprkzbyiqdli.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/af4374ea-28d4-4448-8019-24deb0a2a086.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018678/justinauld/art/mrywre8tuokcd0rolhws.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/7e8b5139-6aef-4377-a415-dbf0818b9cbf.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1458161278/penelope35/art/uqzxi8btomst6geix4wd.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/d8974eec-033e-45b7-9c8b-10ca1057bb10.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454170502/petusy%40comcast.net/art/xnk1cmtyp9y1vhdtwai4.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/1d18a28e-e6c3-4fbe-b5db-081063721ab6.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1459811300/iskra/art/jtxr7toaab0ofdzjevgo.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/1b036bd6-2a5e-4bbe-8a9a-a01eb88d2a20.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1458161235/penelope35/art/b5zbejqzwpiyzctvzntd.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/664ba171-1dbb-4d62-9274-458d1e38adf3.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018668/justinauld/art/vjazupqfvgg6sluianp8.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/e64766eb-56ca-48ca-af7c-d01338d8c84a.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018688/justinauld/art/zr2kmteof0vqjtmozt1j.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/b445502f-48cf-45ac-b432-36c7b7e56cbd.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1457816061/anniemeyer/art/nly4su7aqycguttapmrq.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/44da21f3-a3b5-4c77-861b-8d220cb00a18.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1461913580/gennadraper/art/xlt6xcl7bworluwaw3ef.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/a8b256bf-1a51-4dd4-a7be-55031826e522.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1460135562/tracip/art/btgltevagp0wprlxczus.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/8531523a-d6a4-4ac3-986a-28602a065d72.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453504605/bettyjo/art/isys7zcje6tf8skrywnb.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/d746003f-3b71-4321-a354-0013bd0d4dac.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454171563/petusy%40comcast.net/art/nigmsde83h9pvukidmru.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/92fcebe6-144d-48d4-956f-dc62ba04f8f6.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454985397/williampark/art/jsb1llcdctbmljix6rwu.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/d81094b6-8b88-49b7-ade6-4e4651b3d4d4.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454958386/bassborgmann%40comcast.net/art/pgzojoezlkjenm3hwvxq.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/469c38e2-39d7-4b31-ac33-8f5826952328.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1456953780/jkeckler/art/n897m6wctxjjpbjwrto5.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/dd2b0a03-3a7b-43dc-945f-4585218e98dd.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454018683/justinauld/art/jnngcbsvpvilxpsilsiv.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/b82ddcc5-e67a-43ac-9394-4853198bb11b.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1457230206/jenileeart/art/mspbncx5culzmjtq7qgh.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/978a215c-8db3-4924-ac3b-4067f8fd4613.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1454168138/petusy%40comcast.net/art/qu0gcfxawsrox3x9wwei.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/10a3ad20-92b2-4f9f-9ebd-61957fb2d759.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1456446277/kellywilliamsart/art/xgysqndz0z71ts3egum4.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/bde02ea7-94f1-4dff-83f0-a739a5a5a6a5.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1453516782/jstorq/art/ddp67kyjwc3bwltsinmq.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/4b187647-7d8d-4d6b-a15e-b2a06f8b3cbc.jpg
# Downloading https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1464715634/pardue/art/iw4vaij2vqbp124w9lwz.jpg to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3692/58fff41e-d0ed-40c1-afb6-df50a0906e00.jpg
# Failed to download https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1464715634/pardue/art/iw4vaij2vqbp124w9lwz.jpg: HTTP response code said error
# This trial license of GraphLab Create is assigned to dato2@rc.drizl.co and will expire on July 22, 2016. Please contact trial@dato.com for licensing options or to request a free non-commercial license for personal or academic use.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-5-8363a88f60f4> in <module>()
#       2 #Should take a few minutes - grabbing all images. Future iteration will save image number %APPDATA% to just grab deltas
#       3 url_sarray = gl.SArray(url_list)
# ----> 4 image_sarray = url_sarray.apply(lambda x: gl.Image(x))
#       5 #images = gl.SFrame({'image':image_sarray})
#
# C:\Users\drizl\Anaconda2\envs\dato-env\lib\site-packages\graphlab\data_structures\sarray.pyc in apply(self, fn, dtype, skip_undefined, seed)
#    1675         assert callable(fn), "Input function must be callable."
#    1676
# -> 1677         dryrun = [fn(i) for i in self.head(100) if i is not None]
#    1678         if dtype == None:
#    1679             dtype = infer_type_of_list(dryrun)
#
# <ipython-input-5-8363a88f60f4> in <lambda>(x)
#       2 #Should take a few minutes - grabbing all images. Future iteration will save image number %APPDATA% to just grab deltas
#       3 url_sarray = gl.SArray(url_list)
# ----> 4 image_sarray = url_sarray.apply(lambda x: gl.Image(x))
#       5 #images = gl.SFrame({'image':image_sarray})
#
# C:\Users\drizl\Anaconda2\envs\dato-env\lib\site-packages\graphlab\data_structures\image.pyc in __init__(self, path, format, **_Image__internal_kw_args)
#      70             from ..util import _make_internal_url
#      71             from .. import extensions as _extensions
# ---> 72             img = _extensions.load_image(_make_internal_url(path), format)
#      73             for key, value in list(img.__dict__.items()):
#      74                 setattr(self, key, value)
#
# C:\Users\drizl\Anaconda2\envs\dato-env\lib\site-packages\graphlab\extensions.pyc in <lambda>(*args, **kwargs)
#     166
#     167 def _make_injected_function(fn, arguments):
# --> 168     return lambda *args, **kwargs: _run_toolkit_function(fn, arguments, args, kwargs)
#     169
#     170 def _class_instance_from_name(class_name, *arg, **kwarg):
#
# C:\Users\drizl\Anaconda2\envs\dato-env\lib\site-packages\graphlab\extensions.pyc in _run_toolkit_function(fnname, arguments, args, kwargs)
#     155     if ret[0] != True:
#     156         if len(ret[1]) > 0:
# --> 157             raise _ToolkitError(ret[1])
#     158         else:
#     159             raise _ToolkitError("Toolkit failed with unknown error")
#
# ToolkitError: Cannot open https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1464715634/pardue/art/iw4vaij2vqbp124w9lwz.jpg for read. Fail to download from https://res.cloudinary.com/drizlalpha/image/upload/c_fill,g_center,h_256,w_256/v1464715634/pardue/art/iw4vaij2vqbp124w9lwz.jpg. HTTP response code said error

# %%
###GRAB PRETRAINED MODEL###
#Takes a minute
pretrained_model = gl.load_model('http://s3.amazonaws.com/dato-datasets/deeplearning/imagenet_model_iter45')
# Out:
# Downloading http://s3.amazonaws.com/dato-datasets/deeplearning/imagenet_model_iter45/dir_archive.ini to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3708/6a3bcf21-5ee0-48fb-8eb5-ca3abe56146f.ini
# Downloading http://s3.amazonaws.com/dato-datasets/deeplearning/imagenet_model_iter45/objects.bin to C:/Users/drizl/AppData/Local/Temp/2/graphlab-drizl/3708/cb436e68-cd90-4ca5-a063-78190d80f079.bin

# %%
###EXTRACT FEATURES###
#this step might take a hot minute (10-20 minutes)
images['extracted_features'] = pretrained_model.extract_features(images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b1f5993ec22a> in <module>()
#       2 #u kno, like contours
#       3 #this step might take a hot minute (like 10-20 minutes)
# ----> 4 images['extracted_features'] = pretrained_model.extract_features(images)
#
# NameError: name 'images' is not defined

# %%
###KMEANS CLUSTERING###
#Creates SFrame object using the extracted features
#Change num_clusters number to change the number of clusers 
sf = gl.SFrame(images['extracted_features'])
model = graphlab.kmeans.create(sf, num_clusters=20)
# Out:
# Batch size is larger than the input dataset. Switching to an exact Kmeans method.
# Choosing initial cluster centers with Kmeans++.
# +---------------+-----------+
# | Center number | Row index |
# +---------------+-----------+
# | 0             | 102       |
# | 1             | 117       |
# | 2             | 410       |
# | 3             | 131       |
# | 4             | 197       |
# | 5             | 141       |
# | 10            | 241       |
# +---------------+-----------+
# Starting kmeans model training.
# Assigning points to initial cluster centers.
# +-----------+-------------------------------+
# | Iteration | Number of changed assignments |
# +-----------+-------------------------------+
# | 1         | 89                            |
# | 2         | 46                            |
# | 3         | 27                            |
# | 4         | 19                            |
# | 5         | 11                            |
# | 6         | 2                             |
# | 7         | 1                             |
# | 8         | 0                             |
# +-----------+-------------------------------+

# %%
###CREATE SARRAY AND ADD URLs###
#you know, just to have everything in one place
sa = gl.SArray(url_list)
model.cluster_id.add_column(sa)
# Out:
# Columns:
# 	row_id	int
# 	cluster_id	int
# 	distance	float
# 	X4	str
#
# Rows: 514
#
# Data:
# +--------+------------+---------------+-------------------------------+
# | row_id | cluster_id |    distance   |               X4              |
# +--------+------------+---------------+-------------------------------+
# |   0    |     15     | 48.0686225891 | https://res.cloudinary.com... |
# |   1    |     15     | 46.4741401672 | https://res.cloudinary.com... |
# |   2    |     15     | 49.6456222534 | https://res.cloudinary.com... |
# |   3    |     14     | 31.2243251801 | https://res.cloudinary.com... |
# |   4    |     14     | 57.4188728333 | https://res.cloudinary.com... |
# |   5    |     14     |  33.010269165 | https://res.cloudinary.com... |
# |   6    |     15     | 49.5647010803 | https://res.cloudinary.com... |
# |   7    |     14     | 33.6668434143 | https://res.cloudinary.com... |
# |   8    |     15     | 47.7299690247 | https://res.cloudinary.com... |
# |   9    |     2      | 41.1428070068 | https://res.cloudinary.com... |
# +--------+------------+---------------+-------------------------------+
# [514 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
###TURN TO JSON###
#First parameter controls where it gets outputed - specify file path if you have a preference
model.cluster_id.export_json('output.json', orient = 'records')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-744e4fd80baa> in <module>()
#       2 #'cause XML sucks
#       3 #First parameter controls where it gets outputed - specify file path if you have a preference
# ----> 4 model.cluster_id.export_json('output.json', orient = 'records')
#
# NameError: name 'model' is not defined
